# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df =pd.read_csv('salaries.csv')

# %%
df.shape
# Out:
# (105434, 11)

# %%
df.head()
# Out:
#    work_year experience_level employment_type      job_title  salary  \
# 0       2025               EN              FT   Data Analist   65664
# 1       2025               EN              FT   Data Analist   47652
# 2       2025               EN              FT  Data Engineer  158113
# 3       2025               EN              FT  Data Engineer   87795
# 4       2025               EX              FT  Data Engineer  351410
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             EUR          69120                 NL             0
# 1             EUR          50160                 NL             0
# 2             USD         158113                 US             0
# 3             USD          87795                 US             0
# 4             USD         351410                 US             0
#
#   company_location company_size
# 0               NL            M
# 1               NL            M
# 2               US            M
# ...

# %%
df.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 105429    False
# 105430    False
# 105431    False
# 105432    False
# 105433    False
# Length: 105434, dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105434 entries, 0 to 105433
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   work_year           105434 non-null  int64
#  1   experience_level    105434 non-null  object
#  2   employment_type     105434 non-null  object
#  3   job_title           105434 non-null  object
#  4   salary              105434 non-null  int64
#  5   salary_currency     105434 non-null  object
#  6   salary_in_usd       105434 non-null  int64
#  7   employee_residence  105434 non-null  object
#  8   remote_ratio        105434 non-null  int64
#  9   company_location    105434 non-null  object
#  10  company_size        105434 non-null  object
# dtypes: int64(4), object(7)
# memory usage: 8.8+ MB

# %%
df.describe()
# Out:
#            work_year        salary  salary_in_usd   remote_ratio
# count  105434.000000  1.054340e+05  105434.000000  105434.000000
# mean     2024.188981  1.626908e+05  158018.514179      21.103249
# std         0.669665  2.137236e+05   74401.714026      40.714744
# min      2020.000000  1.400000e+04   15000.000000       0.000000
# 25%      2024.000000  1.064000e+05  106400.000000       0.000000
# 50%      2024.000000  1.471000e+05  147000.000000       0.000000
# 75%      2025.000000  1.997000e+05  199000.000000       0.000000
# max      2025.000000  3.040000e+07  800000.000000     100.000000

# %%
df.tail()
# Out:
#         work_year experience_level employment_type                 job_title  \
# 105429       2020               SE              FT            Data Scientist
# 105430       2021               MI              FT  Principal Data Scientist
# 105431       2020               EN              FT            Data Scientist
# 105432       2020               EN              CT     Business Data Analyst
# 105433       2021               SE              FT            Data Scientist
#
#          salary salary_currency  salary_in_usd employee_residence  \
# 105429   412000             USD         412000                 US
# 105430   151000             USD         151000                 US
# 105431   105000             USD         105000                 US
# 105432   100000             USD         100000                 US
# 105433  7000000             INR          94665                 IN
#
#         remote_ratio company_location company_size
# 105429           100               US            L
# ...

# %%
df['job_title'].unique()
# Out:
# array(['Data Analist', 'Data Engineer', 'Engineer', 'Systems Engineer',
#        'Analytics Engineer', 'Data Architect', 'Data Manager',
#        'BI Developer', 'Machine Learning Engineer',
#        'Machine Learning Scientist', 'Business Intelligence Developer',
#        'Product Manager', 'Data Scientist', 'AI Engineer',
#        'Data Specialist', 'Research Engineer', 'Data Analyst',
#        'Software Developer', 'Analyst', 'Software Engineer',
#        'Site Reliability Engineer', 'Applied Scientist',
#        'Computer Vision Engineer', 'Research Scientist',
#        'Data Analytics Manager', 'Manager', 'AI Architect',
#        'Data Developer', 'Solutions Architect', 'Architect', 'Stage',
#        'Research Assistant', 'Business Intelligence Analyst',
#        'Data Integration Engineer', 'Data Lead', 'Associate',
#        'Quantitative Researcher', 'Business Intelligence Engineer',
#        'Software Development Engineer', 'Data Management Specialist',
# ...

# %%
df['job_title'].value_counts()
# Out:
# job_title
# Data Scientist               14938
# Data Engineer                12392
# Software Engineer            11635
# Data Analyst                 10024
# Machine Learning Engineer     7169
#                              ...
# BI Data Engineer                 1
# Data Science Tech Lead           1
# Marketing Data Engineer          1
# Principal Data Architect         1
# Cloud Data Architect             1
# Name: count, Length: 347, dtype: int64

# %%
df['experience_level'].unique()
# Out:
# array(['EN', 'EX', 'SE', 'MI'], dtype=object)

# %%
df['experience_level'].value_counts()
# Out:
# experience_level
# SE    61396
# MI    31802
# EN     9938
# EX     2298
# Name: count, dtype: int64

# %%
plt.hist(df['salary_in_usd'],bins=30)
# Out:
# (array([1.5170e+03, 5.8720e+03, 1.1783e+04, 1.5383e+04, 1.7656e+04,
#         1.4746e+04, 1.1991e+04, 9.4720e+03, 6.4570e+03, 3.7640e+03,
#         2.8970e+03, 1.2970e+03, 1.0550e+03, 4.4100e+02, 3.0400e+02,
#         2.5300e+02, 1.4700e+02, 6.6000e+01, 9.4000e+01, 4.3000e+01,
#         4.4000e+01, 6.0000e+00, 2.9000e+01, 1.3000e+01, 7.0000e+00,
#         4.0000e+00, 7.1000e+01, 1.0000e+00, 1.6000e+01, 5.0000e+00]),
#  array([ 15000.        ,  41166.66666667,  67333.33333333,  93500.        ,
#         119666.66666667, 145833.33333333, 172000.        , 198166.66666667,
#         224333.33333333, 250500.        , 276666.66666667, 302833.33333333,
#         329000.        , 355166.66666667, 381333.33333333, 407500.        ,
#         433666.66666667, 459833.33333333, 486000.        , 512166.66666667,
#         538333.33333333, 564500.        , 590666.66666667, 616833.33333333,
#         643000.        , 669166.66666667, 695333.33333333, 721500.        ,
# ...

# %%
top_job =df['job_title'].value_counts().head().index
subset =df[df['job_title'].isin(top_job)]
plt.figure(figsize=(8,5))
plt.scatter(subset['job_title'],subset['salary_in_usd'])

# %%
sns.scatterplot(x=df['experience_level'],y=df['salary_in_usd'],data=df)
# Out:
# <Axes: xlabel='experience_level', ylabel='salary_in_usd'>

# %%
sns.scatterplot(x=df['salary_in_usd'],y=df['remote_ratio'],data=df)
# Out:
# <Axes: xlabel='salary_in_usd', ylabel='remote_ratio'>

# %%
sns.scatterplot(x=df['salary_in_usd'],y=df['company_size'],data=df)
# Out:
# <Axes: xlabel='salary_in_usd', ylabel='company_size'>

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
df.head(1)
# Out:
#    work_year experience_level employment_type     job_title  salary  \
# 0       2025               EN              FT  Data Analist   65664
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             EUR          69120                 NL             0
#
#   company_location company_size
# 0               NL            M

# %%
sns.countplot(x=df['company_size'])
# Out:
# <Axes: xlabel='company_size', ylabel='count'>

# %%
sns.histplot(x=df['work_year'],bins=5)
# Out:
# <Axes: xlabel='work_year', ylabel='Count'>

# %%
sns.boxplot(x=df['remote_ratio'],y=df['salary_in_usd'])
# Out:
# <Axes: xlabel='remote_ratio', ylabel='salary_in_usd'>

# %%
sns.stripplot(x=df['company_size'],y=df['salary_in_usd'])
# Out:
# <Axes: xlabel='company_size', ylabel='salary_in_usd'>

# %%
from sklearn.preprocessing import LabelEncoder
le =LabelEncoder()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105434 entries, 0 to 105433
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   work_year           105434 non-null  int64
#  1   experience_level    105434 non-null  object
#  2   employment_type     105434 non-null  object
#  3   job_title           105434 non-null  object
#  4   salary              105434 non-null  int64
#  5   salary_currency     105434 non-null  object
#  6   salary_in_usd       105434 non-null  int64
#  7   employee_residence  105434 non-null  object
#  8   remote_ratio        105434 non-null  int64
#  9   company_location    105434 non-null  object
#  10  company_size        105434 non-null  object
# dtypes: int64(4), object(7)
# memory usage: 8.8+ MB

# %%
cat =['experience_level','employment_type','job_title','salary_currency','employee_residence','company_location','company_size']
for i in cat:
    df[i]=le.fit_transform(df[i])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105434 entries, 0 to 105433
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   work_year           105434 non-null  int64
#  1   experience_level    105434 non-null  int64
#  2   employment_type     105434 non-null  int64
#  3   job_title           105434 non-null  int64
#  4   salary              105434 non-null  int64
#  5   salary_currency     105434 non-null  int64
#  6   salary_in_usd       105434 non-null  int64
#  7   employee_residence  105434 non-null  int64
#  8   remote_ratio        105434 non-null  int64
#  9   company_location    105434 non-null  int64
#  10  company_size        105434 non-null  int64
# dtypes: int64(11)
# memory usage: 8.8 MB

# %%
x =df.drop(columns=['salary_in_usd'])
y =df['salary_in_usd']

# %%
x =pd.get_dummies(x)

# %%
x
# Out:
#         work_year  experience_level  employment_type  job_title   salary  \
# 0            2025                 0                2         96    65664
# 1            2025                 0                2         96    47652
# 2            2025                 0                2        115   158113
# 3            2025                 0                2        115    87795
# 4            2025                 1                2        115   351410
# ...           ...               ...              ...        ...      ...
# 105429       2020                 3                2        164   412000
# 105430       2021                 2                2        278   151000
# 105431       2020                 0                2        164   105000
# 105432       2020                 0                0         62   100000
# 105433       2021                 3                2        164  7000000
#
#         salary_currency  employee_residence  remote_ratio  company_location  \
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
...     x, y, test_size=0.20, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
se =StandardScaler()
X_train =se.fit_transform(X_train)
X_test =se.fit_transform(X_test)

# %%
#def evaluate_model(name,y_train,y_train_pred,y_test,y_test_pred):
   #pass

# %%
from sklearn.metrics import r2_score,mean_absolute_error,root_mean_squared_error
def evaluate(model,X_train,y_train,X_test,y_test):
    train_pred =model.predict(X_train)
    test_pred =model.predict(X_test)
    print(f"Accuracy for your {model} is:")
    print(f"Training R2 for {model} Is{r2_score(y_train,train_pred)}")
    print(f"Testing R2 socre for {model} is {r2_score(y_test,test_pred)}")
    #MAE
    print(f"Training  MAE for {model} is {mean_absolute_error(y_train,train_pred)}")
    print(f"Testing MAE for {model} is {mean_absolute_error(y_test,test_pred)}")
    #RMSE
    print(f"Training  RMSE for {model} is {root_mean_squared_error(y_train,train_pred)}")
    print(f"Testing RMSE for {model} is {root_mean_squared_error(y_test,test_pred)}")

# %%
from sklearn.linear_model import LinearRegression,Ridge
lener_model =LinearRegression()
lener_model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred =lener_model.predict(X_test)

# %%
y_pred_train =lener_model.predict(X_train)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)#testing acuuracy
# Out:
# 0.32121119851652924

# %%
r2_score(y_train,y_pred_train)#traning accuracy
# Out:
# 0.2466710714783773

# %%
from sklearn.model_selection import GridSearchCV

# %%
ridge =Ridge()

# %%
ridge_param ={
    "alpha":[0.1,1,10,50,100]
}

# %%
ridge_search =GridSearchCV(ridge,ridge_param,cv=5)

# %%
ridge_search.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [0.1, 1, 10, 50, 100]})

# %%
best_ridge =ridge_search.best_estimator_

# %%
evaluate(best_ridge,X_train,y_train,X_test,y_test)
# Out:
# Accuracy for your Ridge(alpha=100) is:
# Training R2 for Ridge(alpha=100) Is0.24666249209310143
# Testing R2 socre for Ridge(alpha=100) is 0.3211723647712995
# Training  MAE for Ridge(alpha=100) is 45907.5250235757
# Testing MAE for Ridge(alpha=100) is 43899.35577870732
# Training  RMSE for Ridge(alpha=100) is 64433.51518765071
# Testing RMSE for Ridge(alpha=100) is 61840.36435939636

# %%
#from sklearn.neighbors import KNeighborsRegressor

# %%
#kkn_model =KNeighborsRegressor()

# %%
#kkn_model.fit(X_train,y_train)

# %%
knn_params ={
    'n_neighbors':[1,3,5,7,9,11]
}

# %%
knn_search=GridSearchCV(kkn_model,knn_params,cv=5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 knn_search=GridSearchCV(kkn_model,knn_params,cv=5)
#
# NameError: name 'kkn_model' is not defined

# %%
knn_search.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsRegressor(),
#              param_grid={'n_neighbors': [1, 3, 5, 7, 9, 11]})

# %%
knn_search.best_estimator_
# Out:
# KNeighborsRegressor(n_neighbors=1)

# %%
best_knn =knn_search.best_estimator_

# %%
evaluate(best_knn,X_train,y_train,X_test,y_test)
# Out:
# Accuracy for your KNeighborsRegressor(n_neighbors=1) is:
# Training R2 for KNeighborsRegressor(n_neighbors=1) Is1.0
# Testing R2 socre for KNeighborsRegressor(n_neighbors=1) is 0.7591523751781117
# Training  MAE for KNeighborsRegressor(n_neighbors=1) is 0.0
# Testing MAE for KNeighborsRegressor(n_neighbors=1) is 25901.096030729834
# Training  RMSE for KNeighborsRegressor(n_neighbors=1) is 0.0
# Testing RMSE for KNeighborsRegressor(n_neighbors=1) is 36835.23683422791

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
DT_model =DecisionTreeRegressor()

# %%
DT_param={
    'max_depth':[3,5,7,10],
    "min_samples_split":[2,5,10]
}

# %%
tree_search=GridSearchCV(DT_model,DT_param,cv=5)

# %%
tree_search.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(),
#              param_grid={'max_depth': [3, 5, 7, 10],
#                          'min_samples_split': [2, 5, 10]})

# %%
best_tree =tree_search.best_estimator_

# %%
evaluate(DT_model,X_train,y_train,X_test,y_test)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[134], line 1
# ----> 1 evaluate(DT_model,X_train,y_train,X_test,y_test)
#
# Cell In[105], line 3, in evaluate(model, X_train, y_train, X_test, y_test)
#       2 def evaluate(model,X_train,y_train,X_test,y_test):
# ----> 3     train_pred =model.predict(X_train)
#       4     test_pred =model.predict(X_test)
#       5     print(f"Accuracy for your {model} is:")
#
# File c:\Users\ayush\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:529, in BaseDecisionTree.predict(self, X, check_input)
#     506 def predict(self, X, check_input=True):
#     507     """Predict class or regression value for X.
#     508
#     509     For a classification model, the predicted class for each sample in X is
#    (...)    527         The predicted classes, or the predict values.
#     528     """
# --> 529     check_is_fitted(self)
# ...

# %%
pd.DataFrame({
    "feature":x.columns,
    'importance':best_tree.feature_importances_
}).sort_values(by='importance',ascending=False)
# Out:
#               feature    importance
# 4              salary  9.827231e-01
# 5     salary_currency  1.401162e-02
# 8    company_location  2.423516e-03
# 6  employee_residence  5.588867e-04
# 0           work_year  1.489922e-04
# 1    experience_level  8.687400e-05
# 3           job_title  4.613211e-05
# 9        company_size  9.013689e-07
# 7        remote_ratio  1.591389e-08
# 2     employment_type  0.000000e+00

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
RF_model =RandomForestRegressor()

# %%
RD_param ={
    "n_estimators":[50,100,150],
    "max_depth":[5,10,15],
    "max_features":['sqrt','log2']
    
}

# %%
Rf_search=GridSearchCV(RF_model,RD_param,cv=5)

# %%
Rf_search.fit(X_train,y_train)

# %%
best_RF =Rf_search.best_estimator_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 best_RF =Rf_search.best_estimator_
#
# AttributeError: 'GridSearchCV' object has no attribute 'best_estimator_'

# %%
evaluate(best_RF,X_train,y_train,X_test,y_test)
# Out:
# Accuracy for your RandomForestRegressor(max_depth=15, max_features='log2') is:
# Training R2 for RandomForestRegressor(max_depth=15, max_features='log2') Is0.997744153034437
# Testing R2 socre for RandomForestRegressor(max_depth=15, max_features='log2') is 0.8361483109745493
# Traing MAE for RandomForestRegressor(max_depth=15, max_features='log2') is 1711.4510410019902
# Testing MAE for RandomForestRegressor(max_depth=15, max_features='log2') is 23282.786646299206
# Traing  RMSE for RandomForestRegressor(max_depth=15, max_features='log2') is 3525.915066259167
# Traing RMSE for RandomForestRegressor(max_depth=15, max_features='log2') is 30382.096856898323

# %%
import joblib

# %%
bandel ={
    'best_model':best_RF,
    "scaler":se,
    "feature_columns":list(x.columns)
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[140], line 2
#       1 bandel ={
# ----> 2     'best_model':best_RF,
#       3     "scaler":se,
#       4     "feature_columns":list(x.columns)
#       5 }
#
# NameError: name 'best_RF' is not defined
